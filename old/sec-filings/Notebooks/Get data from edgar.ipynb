# %%
import pandas as pd
import feedparser
import requests
from datetime import date
from bs4 import BeautifulSoup

# %%
def build_feed_url(cik):
    base_url = "https://www.sec.gov/cgi-bin/browse-edgar"
    params = {
        'action': 'getcompany',
        'CIK': cik,
        'type': 'SD',
        'owner': 'exclude',
        'start': 0,
        'count': 40,
        'output': 'atom',
    }
    req = requests.Request('GET', base_url, params=params)
    prepped = req.prepare()
    return prepped.url

# %%
cik_codes_1 = pd.read_csv('clean_ciks_good.csv')
cik_codes_1 = cik_codes_1.drop('Unnamed: 0', axis=1)
cik_codes_1.head()
# Out:
#        cik          companyname  entityid       primaryexchange primarysymbol  \
# 0   706688          AARON'S INC      2480                  NYSE           AAN
# 1   824142             AAON INC       938  Nasdaq Global Market          AAON
# 2   881890           ABAXIS INC     11929  Nasdaq Global Market          ABAX
# 3  1551152          ABBVIE INC.    883230                  NYSE          ABBV
# 4     1800  ABBOTT LABORATORIES      5054                  NYSE           ABT
#
#    siccode                                     sicdescription
# 0     7359  Equipment Rental and Leasing, Not Elsewhere Cl...
# 1     3585  Air-Conditioning and Warm Air Heating Equipmen...
# 2     3829  Measuring and Controlling Devices, Not Elsewhe...
# 3     2834                        Pharmaceutical Preparations
# 4     2834                        Pharmaceutical Preparations

# %%
cik_codes_2 = pd.read_csv('clean_ciks_good_2.csv')
cik_codes_2 = cik_codes_2.drop('Unnamed: 0', axis=1)
cik_codes_2.head()
# Out:
#        cik                  companyname  entityid       primaryexchange  \
# 0  1433660  JOHN BEAN TECHNOLOGIES CORP    777176                  NYSE
# 1    72903              XCEL ENERGY INC      1763                  NYSE
# 2   789933         NACCO INDUSTRIES INC      1939                  NYSE
# 3   200406            JOHNSON & JOHNSON     10313                  NYSE
# 4  1442145       VERISK ANALYTICS, INC.    785278  Nasdaq Global Market
#
#   primarysymbol  siccode                                     sicdescription
# 0           JBT     3550    Special Industry Machinery, Except Metalworking
# 1           XEL     4931               Electric and Other Services Combined
# 2            NC     3630                               Household Appliances
# 3           JNJ     2834                        Pharmaceutical Preparations
# 4          VRSK     7374  Computer Processing and Data Preparation and P...

# %%
cik_codes = pd.concat([cik_codes_1, cik_codes_2], ignore_index=True)
cik_codes['feed_url'] = cik_codes.cik.apply(build_feed_url)
cik_codes['SD_url_2014'] = ''
cik_codes['SD_url_2015'] = ''
cik_codes['SD_url_2016'] = ''
cik_codes['feed_retrieved_date'] = date.today()  # Note: should do it with the next step, but ok for now
cik_codes.to_csv('all_cik_codes.csv')
cik_codes.head()
# Out:
#        cik          companyname  entityid       primaryexchange primarysymbol  \
# 0   706688          AARON'S INC      2480                  NYSE           AAN
# 1   824142             AAON INC       938  Nasdaq Global Market          AAON
# 2   881890           ABAXIS INC     11929  Nasdaq Global Market          ABAX
# 3  1551152          ABBVIE INC.    883230                  NYSE          ABBV
# 4     1800  ABBOTT LABORATORIES      5054                  NYSE           ABT
#
#    siccode                                     sicdescription  \
# 0     7359  Equipment Rental and Leasing, Not Elsewhere Cl...
# 1     3585  Air-Conditioning and Warm Air Heating Equipmen...
# 2     3829  Measuring and Controlling Devices, Not Elsewhe...
# 3     2834                        Pharmaceutical Preparations
# 4     2834                        Pharmaceutical Preparations
#
#                                             feed_url SD_url_2014 SD_url_2015  \
# 0  https://www.sec.gov/cgi-bin/browse-edgar?owner...
# 1  https://www.sec.gov/cgi-bin/browse-edgar?owner...
# 2  https://www.sec.gov/cgi-bin/browse-edgar?owner...
# 3  https://www.sec.gov/cgi-bin/browse-edgar?owner...
# 4  https://www.sec.gov/cgi-bin/browse-edgar?owner...
#
#   SD_url_2016 feed_retrieved_date
# 0                      2016-04-30
# 1                      2016-04-30
# 2                      2016-04-30
# 3                      2016-04-30
# 4                      2016-04-30

# %% [markdown]
# ## Get EDGAR RSS Feed of Special Disclosures by Company

# %%
def get_feed_and_parse(row):
    feed_url = row.feed_url
    feed = feedparser.parse(feed_url)
    for entry in feed.entries:
        str_date = entry['filing-date']
        date = datetime.strptime(str_date, '%Y-%m-%d')
        year = date.year
        links = entry['links']
        if len(links) > 1:
            print('More than one link')
            print(entry)
        
        if year not in [2014, 2015, 2016]:
            print('Other Year')
            print(entry)
        else:
            column = 'SD_url_%s' % year
            row.loc[column] = links[0]['href']
    return row

# %%
# EXPENSIVE - run carefully
#cik_codes_with_feeds = cik_codes.apply(get_feed_and_parse, axis=1)

# %%
cik_codes_with_feeds.to_csv('cik_codes_with_feed_urls.csv', index_label='id')

# %% [markdown]
# ## Get EDGAR Page for a year and scrape out all the disclosure documents

# %%
cik_codes_with_feeds = pd.read_csv('cik_codes_with_feed_urls.csv')
cik_codes_with_feeds = cik_codes_with_feeds.drop('id', axis=1)
cik_codes_with_feeds.head()
# Out:
#        cik          companyname  entityid       primaryexchange primarysymbol  \
# 0   706688          AARON'S INC      2480                  NYSE           AAN
# 1   824142             AAON INC       938  Nasdaq Global Market          AAON
# 2   881890           ABAXIS INC     11929  Nasdaq Global Market          ABAX
# 3  1551152          ABBVIE INC.    883230                  NYSE          ABBV
# 4     1800  ABBOTT LABORATORIES      5054                  NYSE           ABT
#
#    siccode                                     sicdescription  \
# 0     7359  Equipment Rental and Leasing, Not Elsewhere Cl...
# 1     3585  Air-Conditioning and Warm Air Heating Equipmen...
# 2     3829  Measuring and Controlling Devices, Not Elsewhe...
# 3     2834                        Pharmaceutical Preparations
# 4     2834                        Pharmaceutical Preparations
#
#                                             feed_url  \
# 0  https://www.sec.gov/cgi-bin/browse-edgar?owner...
# 1  https://www.sec.gov/cgi-bin/browse-edgar?owner...
# 2  https://www.sec.gov/cgi-bin/browse-edgar?owner...
# 3  https://www.sec.gov/cgi-bin/browse-edgar?owner...
# 4  https://www.sec.gov/cgi-bin/browse-edgar?owner...
#
#                                          SD_url_2014  \
# 0  http://www.sec.gov/Archives/edgar/data/706688/...
# 1  http://www.sec.gov/Archives/edgar/data/824142/...
# 2  http://www.sec.gov/Archives/edgar/data/881890/...
# 3  http://www.sec.gov/Archives/edgar/data/1551152...
# 4  http://www.sec.gov/Archives/edgar/data/1800/00...
#
#                                          SD_url_2015 SD_url_2016  \
# 0  http://www.sec.gov/Archives/edgar/data/706688/...         NaN
# 1  http://www.sec.gov/Archives/edgar/data/824142/...         NaN
# 2  http://www.sec.gov/Archives/edgar/data/881890/...         NaN
# 3  http://www.sec.gov/Archives/edgar/data/1551152...         NaN
# 4  http://www.sec.gov/Archives/edgar/data/1800/00...         NaN
#
#   feed_retrieved_date
# 0          2016-04-30
# 1          2016-04-30
# 2          2016-04-30
# 3          2016-04-30
# 4          2016-04-30

# %%
# Some test data
subset = cik_codes_with_feeds.copy()
subset = subset[0:1]
subset
# Out:
#       cik  companyname  entityid primaryexchange primarysymbol  siccode  \
# 0  706688  AARON'S INC      2480            NYSE           AAN     7359
#
#                                       sicdescription  \
# 0  Equipment Rental and Leasing, Not Elsewhere Cl...
#
#                                             feed_url  \
# 0  https://www.sec.gov/cgi-bin/browse-edgar?owner...
#
#                                          SD_url_2014  \
# 0  http://www.sec.gov/Archives/edgar/data/706688/...
#
#                                          SD_url_2015 SD_url_2016  \
# 0  http://www.sec.gov/Archives/edgar/data/706688/...         NaN
#
#   feed_retrieved_date
# 0          2016-04-30

# %%
# Data Processing methods

def get_soup(url, i=-1):
    page_response = requests.get(url)
    print(i, page_response.status_code)
    if page_response.status_code != 200:
        return None
    soup = BeautifulSoup(page_response.content, 'html.parser')
    return soup

def get_meta_dict_from_soup(soup):
    company_info = soup.find(class_='companyInfo')
    company_name_cik = company_info.find(class_='companyName').text
    try:
        company_name = company_name_cik.split(' (Filer)')[0]
    except:
        company_name = 'XXX: could not parse 1'
    try:
        cik = company_name_cik.split('CIK:')[1].split('(')[0].lstrip().rstrip()
    except:
        cik = 'XXX: could not parse 1'
    try:
        sec_accession_number = list(soup.find(id='secNum').descendants)[-1].split('\n')[0].lstrip()
    except:
        sec_accession_number = 'XXX: could not parse 1'
    try:
        required = None
        for infoHead in soup.findAll(class_='infoHead'):
            if infoHead.text == 'Accepted':
                required = infoHead
        filing_date = required.next_sibling.nextSibling.text
    except:
        filing_date = 'XXX: could not parse 1'
    return {
        'ret_company_name': company_name,
        'ret_cik': cik,
        'ret_sec_accession_number': sec_accession_number,
        'ret_filing_date': filing_date
    }

base_url = "https://www.sec.gov"
def get_docs_from_soup(soup, meta_dict):
    docs = []
    disclosure_components_table = soup.find(class_='tableFile')
    for row in disclosure_components_table.findAll('tr'):
        cols = row.findAll('td')
        all_data = meta_dict.copy()
        if len(cols) == 0:
            # This is the header row
            continue
        if len(cols) > 2:
            try:
                title = cols[1].text
            except:
                title = 'XXX: could not parse 2'
            try:
                description = cols[2].find('a').text
            except:
                description = 'XXX: could not parse 2'
            try:
                url_part = cols[2].find('a').attrs['href']
                url = '%s%s' % (base_url, url_part)
            except:
                url = 'XXX: could not parse 2'
            all_data.update({
                'ret_title': title,
                'ret_url': url,
                'ret_description': description,
            })
        else:
            # This means that it's probably not the header row but something else wierd is happening
            all_data.update({
                'ret_title': 'XXX: could not parse 3',
                'ret_url': 'XXX: could not parse 3',
                'ret_description': 'XXX: could not parse 3',
            })        
        docs.append(all_data)
    return docs

# %%
disclosure_docs = pd.DataFrame()
for i, row in cik_codes_with_feeds.iterrows():
    for col in ['SD_url_2014', 'SD_url_2015']:
        url = row.loc[col]
        if pd.isnull(url):
            # Nothing to do if there's no url
            continue
        soup = get_soup(url, i)
        if not soup:
            # Nothing to do if there's no soup
            continue
        meta_dict = get_meta_dict_from_soup(soup)
        meta_dict.update({
                'req_company_name': row.loc['companyname'],
                'req_cik': row.loc['cik'],
                'req_url': url
            })
        docs = get_docs_from_soup(soup, meta_dict)
        disclosure_docs = pd.concat([disclosure_docs, pd.DataFrame(docs)], ignore_index=True)
disclosure_docs.head()
# Out:
# 0 200
# 0 200
# 1 200
# 1 200
# 2 200
# 2 200
# 3 200
# 3 200
# 4 200
# 4 200
# 5 200
# 5 200
# 6 200
# 7 200
# 7 200
# 8 200
# 8 200
# 9 200
# 9 200
# 10 200
# 10 200
# 11 200
# 11 200
# 12 200
# 12 200
# 13 200
# 13 200
# 14 200
# 14 200
# 15 200
# 15 200
# 16 200
# 16 200
# 17 200
# 17 200
# 18 200
# 18 200
# 19 200
# 19 200
# 20 200
# 20 200
# 21 200
# 21 200
# 22 200
# 22 200
# 23 200
# 23 200
# 24 200
# 24 200
# 25 200
# 25 200
# 26 200
# 26 200
# 27 200
# 27 200
# 28 200
# 28 200
# 29 200
# 30 200
# 30 200
# 31 200
# 31 200
# 32 200
# 32 200
# 33 200
# 33 200
# 34 200
# 34 200
# 35 200
# 35 200
# 36 200
# 36 200
# 37 200
# 38 200
# 38 200
# 39 200
# 39 200
# 40 200
# 40 200
# 41 200
# 41 200
# 42 200
# 42 200
# 43 200
# 43 200
# 44 200
# 44 200
# 45 200
# 45 200
# 46 200
# 46 200
# 47 200
# 47 200
# 48 200
# 48 200
# 49 200
# 49 200
# 50 200
# 50 200
# 51 200
# 51 200
# 52 200
# 52 200
# 53 200
# 53 200
# 54 200
# 54 200
# 55 200
# 55 200
# 56 200
# 56 200
# 57 200
# 57 200
# 58 200
# 58 200
# 59 200
# 59 200
# 60 200
# 60 200
# 61 200
# 61 200
# 62 200
# 62 200
# 63 200
# 63 200
# 64 200
# 64 200
# 65 200
# 65 200
# 66 200
# 66 200
# 67 200
# 67 200
# 68 200
# 68 200
# 69 200
# 69 200
# 70 200
# 70 200
# 71 200
# 71 200
# 72 200
# 72 200
# 73 200
# 73 200
# 74 200
# 74 200
# 75 200
# 75 200
# 76 200
# 76 200
# 77 200
# 77 200
# 78 200
# 78 200
# 79 200
# 79 200
# 80 200
# 80 200
# 81 200
# 81 200
# 82 200
# 83 200
# 83 200
# 85 200
# 85 200
# 86 200
# 86 200
# 87 200
# 87 200
# 88 200
# 88 200
# 89 200
# 89 200
# 90 200
# 90 200
# 91 200
# 91 200
# 92 200
# 92 200
# 93 200
# 93 200
# 94 200
# 94 200
# 95 200
# 95 200
# 96 200
# 96 200
# 97 200
# 97 200
# 98 200
# 98 200
# 99 200
# 99 200
# 100 200
# 100 200
# 101 200
# 101 200
# 102 200
# 102 200
# 103 200
# 103 200
# 104 200
# 104 200
# 105 200
# 105 200
# 106 200
# 106 200
# 107 200
# 107 200
# 108 200
# 108 200
# 109 200
# 109 200
# 110 200
# 110 200
# 111 200
# 111 200
# 112 200
# 112 200
# 113 200
# 113 200
# 114 200
# 115 200
# 115 200
# 116 200
# 116 200
# 117 200
# 117 200
# 118 200
# 118 200
# 119 200
# 119 200
# 120 200
# 120 200
# 121 200
# 121 200
# 122 200
# 122 200
# 737 200
# 740 200
# 740 200
# 741 200
# 741 200
# 742 200
# 742 200
# 743 200
# 743 200
# 744 200
# 744 200
# 745 200
# 745 200
# 746 200
# 746 200
# 749 200
# 749 200
# 751 200
# 751 200
# 753 200
# 753 200
# 754 200
# 754 200
# 755 200
# 755 200
# 757 200
# 757 200
# 759 200
# 759 200
# 760 200
# 760 200
# 761 200
# 761 200
# 762 200
# 762 200
# 763 200
# 763 200
# 764 200
# 764 200
# 765 200
# 765 200
# 766 200
# 766 200
# 769 200
# 769 200
# 771 200
# 771 200
# 772 200
# 772 200
# 773 200
# 773 200
# 774 200
# 774 200
# 775 200
# 776 200
# 776 200
# 777 200
# 777 200
# 778 200
# 778 200
# 779 200
# 779 200
# 781 200
# 781 200
# 783 200
# 783 200
# 787 200
# 787 200
# 794 200
# 794 200
# 795 200
# 795 200
# 796 200
# 796 200
# 801 200
# 801 200
# 804 200
# 804 200
# 806 200
# 806 200
# 809 200
# 809 200
# 812 200
# 812 200
# 813 200
# 813 200
# 814 200
# 814 200
# 816 200
# 817 200
# 819 200
# 819 200
# 821 200
# 821 200
# 823 200
# 823 200
# 827 200
# 828 200
# 828 200
# 829 200
# 829 200
# 831 200
# 831 200
# 832 200
# 832 200
# 834 200
# 834 200
# 837 200
# 837 200
# 838 200
# 838 200
# 839 200
# 839 200
# 840 200
# 840 200
# 842 200
# 842 200
# 843 200
# 843 200
# 844 200
# 844 200
# 847 200
# 847 200
# 848 200
# 848 200
# 850 200
# 852 200
# 852 200
# 853 200
# 853 200
# 855 200
# 855 200
# 857 200
# 857 200
# 865 200
# 865 200
# 866 200
# 866 200
# 867 200
# 867 200
# 868 200
# 869 200
# 869 200
# 872 200
# 872 200
# 873 200
# 873 200
# 875 200
# 875 200
# 877 200
# 877 200
# 878 200
# 878 200
# 880 200
# 880 200
# 883 200
# 883 200
# 886 200
# 886 200
# 888 200
# 888 200
# 890 200
# 890 200
# 891 200
# 891 200
# 893 200
# 893 200
# 894 200
# 894 200
# 895 200
# 895 200
# 896 200
# 896 200
# 898 200
# 898 200
# 900 200
# 900 200
# 901 200
# 901 200
# 902 200
# 902 200
# 907 200
# 907 200
# 908 200
# 908 200
# 909 200
# 910 200
# 910 200
# 912 200
# 913 200
# 913 200
# 915 200
# 915 200
# 916 200
# 916 200
# 919 200
# 921 200
# 921 200
# 922 200
# 924 200
# 924 200
# 927 200
# 927 200
# 928 200
# 928 200
# 931 200
# 931 200
# 932 200
# 932 200
# 933 200
# 933 200
# 934 200
# 934 200
# 936 200
# 936 200
# 938 200
# 938 200
# 939 200
# 939 200
# 940 200
# 941 200
# 942 200
# 942 200
# 943 200
# 943 200
# 945 200
# 945 200
# 947 200
# 947 200
# 953 200
# 953 200
# 956 200
# 956 200
# 958 200
# 958 200
# 959 200
# 959 200
# 960 200
# 960 200
# 962 200
# 962 200
# 963 200
# 963 200
# 965 200
# 965 200
# 966 200
# 966 200
# 967 200
# 968 200
# 968 200
# 969 200
# 969 200
# 970 200
# 973 200
# 973 200
# 974 200
# 974 200
# 976 200
# 976 200
# 979 200
# 979 200
# 980 200
# 980 200
# 983 200
# 983 200
# 1462 200
# 1464 200
# 1464 200
# 1465 200
# 1465 200
# 1468 200
# 1468 200
# 1473 200
# 1473 200
# 1477 200
# 1477 200
# 1478 200
# 1478 200
# 1479 200
# 1479 200
# 1481 200
# 1481 200
# 1483 200
# 1483 200
# 1484 200
# 1484 200
# 1486 200
# 1486 200
# 1487 200
# 1487 200
# 1488 200
# 1488 200
# 1490 200
# 1490 200
# 1491 200
# 1491 200
# 1495 200
# 1495 200
# 1496 200
# 1496 200
# 1497 200
# 1497 200
# 1498 200
# 1498 200
# 1499 200
# 1499 200
# 1502 200
# 1502 200
# 1503 200
# 1503 200
# 1508 200
# 1508 200
# 1513 200
# 1513 200
# 1515 200
# 1515 200
# 1517 200
# 1517 200
# 1521 200
# 1521 200
# 1522 200
# 1522 200
# 1525 200
# 1525 200
# 1527 200
# 1527 200
# 1528 200
# 1528 200
# 1529 200
# 1530 200
# 1530 200
# 1531 200
# 1531 200
# 1533 200
# 1533 200
# 1535 200
# 1535 200
# 1537 200
# 1538 200
# 1538 200
# 1541 200
# 1541 200
# 1542 200
# 1542 200
# 1545 200
# 1545 200
# 1546 200
# 1546 200
# 1549 200
# 1549 200
# 1550 200
# 1550 200
# 1551 200
# 1551 200
# 1554 200
# 1554 200
# 1555 200
# 1555 200
# 1557 200
# 1557 200
# 1560 200
# 1560 200
# 1562 200
# 1562 200
# 1566 200
# 1566 200
# 1567 200
# 1567 200
# 1569 200
# 1569 200
# 1571 200
# 1571 200
#        req_cik  req_company_name  \
# 0  AARON'S INC            706688
# 1  AARON'S INC            706688
# 2  AARON'S INC            706688
# 3  AARON'S INC            706688
# 4     AAON INC            824142
#
#                                              req_url     ret_cik  \
# 0  http://www.sec.gov/Archives/edgar/data/706688/...  0000706688
# 1  http://www.sec.gov/Archives/edgar/data/706688/...  0000706688
# 2  http://www.sec.gov/Archives/edgar/data/706688/...  0000706688
# 3  http://www.sec.gov/Archives/edgar/data/706688/...  0000706688
# 4  http://www.sec.gov/Archives/edgar/data/824142/...  0000824142
#
#   ret_company_name                 ret_description      ret_filing_date  \
# 0      AARON'S INC  formsdconflictminerals2014.htm  2014-05-28 12:50:08
# 1      AARON'S INC        0000706688-14-000029.txt  2014-05-28 12:50:08
# 2      AARON'S INC      sdconflictminerals2014.htm  2015-05-22 12:06:05
# 3      AARON'S INC        0000706688-15-000148.txt  2015-05-22 12:06:05
# 4         AAON INC                 a2013formsd.htm  2014-06-02 13:49:18
#
#   ret_sec_accession_number                      ret_title  \
# 0     0000706688-14-000029                             SD
# 1     0000706688-14-000029  Complete submission text file
# 2     0000706688-15-000148      SD_CONFLICT_MINERALS_2014
# 3     0000706688-15-000148  Complete submission text file
# 4     0000824142-14-000080                 AAON2013FORMSD
#
#                                              ret_url
# 0  https://www.sec.gov/Archives/edgar/data/706688...
# 1  https://www.sec.gov/Archives/edgar/data/706688...
# 2  https://www.sec.gov/Archives/edgar/data/706688...
# 3  https://www.sec.gov/Archives/edgar/data/706688...
# 4  https://www.sec.gov/Archives/edgar/data/824142...

# %%
disclosure_docs.to_csv('disclosure_docs_list.csv')

# %%
len(disclosure_docs)
# Out:
# 5571
